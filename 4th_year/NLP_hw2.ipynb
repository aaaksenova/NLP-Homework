# %% [markdown]
# # Домашняя работа NLP 2

# %% [markdown]
# Выберите корпус отзывов на товары одной из категорий Amazon: http://jmcauley.ucsd.edu/data/amazon/
# (В низу страницы по ссылке есть код для загрузки данных, можете им воспользоваться)
#
# Допустим, что вам нужно подготовить аналитический отчет по этим отзывам — например, для производителя нового продукта этой категории. Для этого будем искать упоминания товаров в отзывах (будем считать их NE). Учтите, что упоминание может выглядеть не только как "Iphone 10", но и как "модель", "телефон" и т.п.
# Важное замечание: в задании приводятся примеры решений, вы можете их использовать!
#
# (3 балла) Предложите 3 способа найти упоминания товаров в отзывах. Например, использовать bootstrapping: составить шаблоны вида "холодильник XXX", найти все соответствующие n-граммы и выделить из них называние товара. Могут помочь заголовки и дополнительные данные с Amazon (Metadata здесь) Какие данные необходимы для каждого из способов? Какие есть достоинства/недостатки? ✅

# %% [markdown]
# **Ответ**
#
# 1. Кластеризовать векторные представления названий продукта из метаданных: так мы получим разные типы продуктов Проранжировать отзывы по "релевантности" к базовому названию продукта. Например, подсчитать bm25. Выделить именные паттерны из топ-10 релевантных отзывов по каждому типу продуктов
#
#
#     + Кластеризация объединит galaxy watch и smart watch
#
#     - В кластеризации обычно куча мусора, тем более, когда она на human generated content
#
#     - Нет уверенности, что релевантность по поиску коррелирует с частотностью NE по отзывам. Люди часто называют вещи не своими именами

# %% [markdown]
# 2. Объединить продукты по категории прописанной в метадате. Выбираем родовое название для категории и находим к нему самых частотных ближайших соседей. Строим по ним n-граммы и ранжируем разными методами. Аггрегируем полученные результаты, чтобы выделить n-граммы, подходящие по нескольким ранжированиям. Затем смотрим, что вышло и применяем фильтры, если нужно
#
#
#     + Полнота будет супер
#
#     + Принимаем решение на основании нескольких метрик
#
#     - Скорее всего есть мусор
#
#     + Он чистится data-driven фильтрами: посмотрим, что вышло в топ и отфильтруем, как нужно
#
#     - Не объединяем galaxy watch и smart watch

# %% [markdown]
#    **Я решила остановиться на этом способе, только еще добавила знание про название товара**

# %% [markdown]
# 3. Выделяем существительные из названия товаров, потом смотрим по данным на самые частотные коллокации с ними и по этому строим паттерны для yargy (вообще для чего-то такого есть библиотека TermExtract, можно извлечь с ее помощью и посмотреть самые частотные + близкие по эмбеддингам коллокации, она извлекает именно термины). TermExtract использовать не вышло, потому что она старая и есть какие-то конфликты версий библиотек
#
#
#     + Самим писать ничего не надо, TermExtract все за нас сделает
#
#     + Паттерны тоже приятный фильтр
#
#     - Когда хорошая точность, часто плохая полнота. Есть риск потерять неожиданные коллокации

# %% [markdown]
# (2 балла) Реализуйте один из предложенных вами способов. Примеры в качестве подсказки (можно использовать один из них): написать правила с помощью natasha/yargy составить мини-словарь сущностей/дескрипторов, расширить с помощью эмбеддингов (например, word2vec) ✅
#
# (1 балл) Соберите n-граммы с полученными сущностями (NE + левый сосед / NE + правый сосед) ✅
#
# (3 балла) Ранжируйте n-граммы с помощью 3 коллокационных метрик (t-score, PMI и т.д.). Не забудьте про частотный фильтр / сглаживание. Выберите лучший результат (какая метрика ранжирует выше коллокации, подходящие для отчёта). ✅
#
# (1 балл) Сгруппируйте полученные коллокации по NE, выведите примеры для 5 товаров. Должны получиться примерно такие группы: ✅
#
# watch stylish watch good watches great watch love this watch ...
#
# Бонус (2 балла): если придумаете способ объединить синонимичные упоминания (например, "Samsung Galaxy Watch", "watch", "smartwatch")

# %%
import json
from tqdm.auto import tqdm
import pandas as pd

# %%
reviews = open('Clothing_Shoes_and_Jewelry_5.json').readlines()

# %%
review = json.loads(reviews[27866])

# %%
review
# Out:
# {'overall': 3.0,
#  'verified': True,
#  'reviewTime': '06 7, 2016',
#  'reviewerID': 'A3GPMIUWL9EB5M',
#  'asin': 'B0000CBALZ',
#  'style': {'Size:': ' 62W x 30L', 'Color:': ' Overdyed Black'},
#  'reviewerName': 'Papaloop',
#  'reviewText': 'Size runs small. Especially in the thigh area.',
#  'summary': 'Three Stars',
#  'unixReviewTime': 1465257600}

# %%
review_texts = [json.loads(r)['reviewText'] for r in reviews]

# %%
meta = open('meta_Clothing_Shoes_and_Jewelry.json').readlines()

# %%
meta = {json.loads(m)['asin'] : {'category' : json.loads(m)['category'], 'title' : json.loads(m)['title'] if 'title' in json.loads(m).keys() else ''} for m in meta}

# %%
review_data = []
for review in reviews:
    try:
        text = json.loads(review)['reviewText']
        idx = json.loads(review)['asin']
        category = meta[idx]['category']
        title = meta[idx]['title']
        review_data.append((text, idx, category, title))
    except:
        continue
# Out:
# Exception ignored in: <function tqdm.__del__ at 0x107b315e0>
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/tqdm/std.py", line 1147, in __del__
#     self.close()
#   File "/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/tqdm/notebook.py", line 286, in close
#     self.disp(bar_style='danger', check_delay=False)
# AttributeError: 'tqdm' object has no attribute 'disp'

# %%
len(reviews)
# Out:
# 11285464

# %%
df = pd.DataFrame(review_data, columns =['review_text', 'product_idx', 'product_category', 'product_title'])

# %%
df.to_csv('reviews_with_meta.csv')

# %%
df['subcategory'] = df['product_category'].apply(lambda x: x[2] if len(x) > 2 else '')

# %%
df['subcategory'].unique()[:50]
# Out:
# array(['Jewelry', 'Clothing', 'Accessories', 'Travel Accessories',
#        'Maternity', 'Imported', 'Men', 'Watches', 'Kids & Baby', 'Women',
#        'Props', 'Briefcases', 'Uniforms, Work & Safety', 'Shoes',
#        'Luggage', 'Messenger Bags', 'Baby Girls', 'Handbags & Wallets',
#        '', 'Baby Boys', 'Shoe Care & Accessories', 'Big & Tall',
#        'Travel Duffels', 'Waist Packs', 'Jewelry Accessories', 'Gym Bags',
#        'Plus-Size', 'Backpacks', 'neoprene', 'chiffon',
#        '80% hi-bulk acrylic / 20% stetch nylon',
#        '85% Polyester, 15% Cotton', 'School Uniforms',
#        'Contemporary & Designer', '100% Leather',
#        'August Birthstone Necklace Perfect for Mothers & Grandmothers',
#        'October Birthstone Necklace Perfect for Mothers & Grandmothers',
#        'May Birthstone Necklace Perfect for Mothers & Grandmothers',
#        'Dupont Supplex 3-ply nylon 7 pockets including cordura lined pliers pocket 27 bar tacks 18" outseam | 7.5" inseam light weight, strong, comfortable stain resistant finish',
#        'steel', 'Umbrellas', "100% Lamb's wool", 'Watch Accessories',
#        'Double sided card holder', 'Cotton',
#        '50% cotton, 50% polyester preshrunk blend fleece', '100% Cotton',
#        'Surf, Skate & Street', 'leather',
#        '100% cotton. Machine wash & dry. Imported.'], dtype=object)

# %% [markdown]
# Разделим товары на мужскую и женскую обувь

# %%
def gender(x):
    if 'Women' in x:
        return 'fem'
    if 'Men' in x:
        return 'm'
    else:
        return ''

# %%
df_shoes = df.loc[df['subcategory'] == 'Shoes']

# %%
df_shoes['gender'] = df_shoes['product_category'].apply(lambda x: gender(x))
# Out:
# /var/folders/b8/zfvmm7h90xvdz7yjjhdtzxvw0000gn/T/ipykernel_62405/3249773513.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_shoes['gender'] = df_shoes['product_category'].apply(lambda x: gender(x))

# %%
fem_shoes = df_shoes.loc[df_shoes.gender == 'fem'][:1000000]
fem_shoes.to_csv('fem_shoes.csv')
fem_shoes
# Out:
#                                                review_text product_idx  \
# 1475     These shoes were recommended to me by a severa...  B00004VWJ3
# 1476                                             Excellent  B00004VWJ3
# 1477     I love these shoes! I have plantar fasciitis a...  B00004VWJ3
# 1478     We take off our shoes in the house, but have 4...  B00004VWJ3
# 1479                                       Good, as always  B00004VWJ3
# ...                                                    ...         ...
# 5252152  I had forgotten that these shoes run small.  I...  B00HGABX0I
# 5252153  Really nice.  Fit is a little large but feel s...  B00HGADFZO
# 5252154  I bought these size 9 shoes for me, but ended ...  B00HGADFZO
# 5252155  LOVE THEM. No breaking in needed. They've been...  B00HGADFZO
# 5252156  After reading the reviews, I ordered 1/2 size ...  B00HGABX0I
#
#                                           product_category  \
# 1475     [Clothing, Shoes & Jewelry, Women, Shoes, Mule...
# 1476     [Clothing, Shoes & Jewelry, Women, Shoes, Mule...
# 1477     [Clothing, Shoes & Jewelry, Women, Shoes, Mule...
# 1478     [Clothing, Shoes & Jewelry, Women, Shoes, Mule...
# 1479     [Clothing, Shoes & Jewelry, Women, Shoes, Mule...
# ...                                                    ...
# 5252152  [Clothing, Shoes & Jewelry, Women, Shoes, Outd...
# 5252153  [Clothing, Shoes & Jewelry, Women, Shoes, Outd...
# 5252154  [Clothing, Shoes & Jewelry, Women, Shoes, Outd...
# 5252155  [Clothing, Shoes & Jewelry, Women, Shoes, Outd...
# 5252156  [Clothing, Shoes & Jewelry, Women, Shoes, Outd...
#
#                                              product_title subcategory gender
# 1475     Birki's Super Pu, Black, 44 M EU (13 Women /11...       Shoes    fem
# 1476     Birki's Super Pu, Black, 44 M EU (13 Women /11...       Shoes    fem
# 1477     Birki's Super Pu, Black, 44 M EU (13 Women /11...       Shoes    fem
# 1478     Birki's Super Pu, Black, 44 M EU (13 Women /11...       Shoes    fem
# 1479     Birki's Super Pu, Black, 44 M EU (13 Women /11...       Shoes    fem
# ...                                                    ...         ...    ...
# 5252152                     KEEN Women's Koven Hiking Shoe       Shoes    fem
# 5252153     KEEN Women's Durand Low Waterproof Hiking Shoe       Shoes    fem
# 5252154     KEEN Women's Durand Low Waterproof Hiking Shoe       Shoes    fem
# 5252155     KEEN Women's Durand Low Waterproof Hiking Shoe       Shoes    fem
# 5252156                     KEEN Women's Koven Hiking Shoe       Shoes    fem
#
# [1000000 rows x 6 columns]

# %%
m_shoes = df_shoes.loc[df_shoes.gender == 'm']
m_shoes.to_csv('m_shoes.csv')
m_shoes
# Out:
#                                                 review_text product_idx  \
# 1977      i love these shoes. i ware them alot. i have t...  B00006XXGO
# 1978      this is the best shoe I have ever bought. I lo...  B00006XXGO
# 1979      Lord, could Converse have got it any more righ...  B00006XXGO
# 1980      What can I say?I love this shoe,there awesome....  B00006XXGO
# 1981      When basketballer Charles "Chuck" Taylor walke...  B00006XXGO
# ...                                                     ...         ...
# 11275547  Looks okay in the picture here but material ha...  B01HJH7W0W
# 11275548  I like these shoes. After hit and miss of shoe...  B01HJH7W0W
# 11275549  Nice, I wore these to a dress event and they l...  B01HJH7W0W
# 11275550  Love the shoes! I get compliments all the time...  B01HJH7W0W
# 11275551               A little tight. Quality and style A+  B01HJH7W0W
#
#                                            product_category  \
# 1977      [Clothing, Shoes & Jewelry, Men, Shoes, Fashio...
# 1978      [Clothing, Shoes & Jewelry, Men, Shoes, Fashio...
# 1979      [Clothing, Shoes & Jewelry, Men, Shoes, Fashio...
# 1980      [Clothing, Shoes & Jewelry, Men, Shoes, Fashio...
# 1981      [Clothing, Shoes & Jewelry, Men, Shoes, Fashio...
# ...                                                     ...
# 11275547   [Clothing, Shoes & Jewelry, Men, Shoes, Oxfords]
# 11275548   [Clothing, Shoes & Jewelry, Men, Shoes, Oxfords]
# 11275549   [Clothing, Shoes & Jewelry, Men, Shoes, Oxfords]
# 11275550   [Clothing, Shoes & Jewelry, Men, Shoes, Oxfords]
# 11275551   [Clothing, Shoes & Jewelry, Men, Shoes, Oxfords]
#
#                                               product_title subcategory gender
# 1977      Converse Chuck Taylor All Star Canvas Low Top ...       Shoes      m
# 1978      Converse Chuck Taylor All Star Canvas Low Top ...       Shoes      m
# 1979      Converse Chuck Taylor All Star Canvas Low Top ...       Shoes      m
# 1980      Converse Chuck Taylor All Star Canvas Low Top ...       Shoes      m
# 1981      Converse Chuck Taylor All Star Canvas Low Top ...       Shoes      m
# ...                                                     ...         ...    ...
# 11275547                    Deer Stags Men's Hampden Oxford       Shoes      m
# 11275548                    Deer Stags Men's Hampden Oxford       Shoes      m
# 11275549                    Deer Stags Men's Hampden Oxford       Shoes      m
# 11275550                    Deer Stags Men's Hampden Oxford       Shoes      m
# 11275551                    Deer Stags Men's Hampden Oxford       Shoes      m
#
# [915759 rows x 6 columns]

# %% [markdown]
# # Загружаем данные

# %% [markdown]
# Понятно, что абсолютный путь это плохо, но данные много весят и на гитхаб не влезут, поэтому, кажется, запустить все равно не выйдет(

# %%
! unzip '/Users/a19336136/Downloads/Telegram Desktop/fem_shoes.csv.zip'
# Out:
# Archive:  /Users/a19336136/Downloads/Telegram Desktop/fem_shoes.csv.zip
#   inflating: fem_shoes.csv

# %%
df_fem = pd.read_csv('fem_shoes.csv')

# %%
df_fem[:50]
# Out:
#         Unnamed: 0                                        review_text  \
# 0             1475  These shoes were recommended to me by a severa...
# 1             1476                                          Excellent
# 2             1477  I love these shoes! I have plantar fasciitis a...
# 3             1478  We take off our shoes in the house, but have 4...
# 4             1479                                    Good, as always
# ...            ...                                                ...
# 999995     5252152  I had forgotten that these shoes run small.  I...
# 999996     5252153  Really nice.  Fit is a little large but feel s...
# 999997     5252154  I bought these size 9 shoes for me, but ended ...
# 999998     5252155  LOVE THEM. No breaking in needed. They've been...
# 999999     5252156  After reading the reviews, I ordered 1/2 size ...
#
#        product_idx                                   product_category  \
# 0       B00004VWJ3  ['Clothing, Shoes & Jewelry', 'Women', 'Shoes'...
# 1       B00004VWJ3  ['Clothing, Shoes & Jewelry', 'Women', 'Shoes'...
# 2       B00004VWJ3  ['Clothing, Shoes & Jewelry', 'Women', 'Shoes'...
# 3       B00004VWJ3  ['Clothing, Shoes & Jewelry', 'Women', 'Shoes'...
# 4       B00004VWJ3  ['Clothing, Shoes & Jewelry', 'Women', 'Shoes'...
# ...            ...                                                ...
# 999995  B00HGABX0I  ['Clothing, Shoes & Jewelry', 'Women', 'Shoes'...
# 999996  B00HGADFZO  ['Clothing, Shoes & Jewelry', 'Women', 'Shoes'...
# 999997  B00HGADFZO  ['Clothing, Shoes & Jewelry', 'Women', 'Shoes'...
# 999998  B00HGADFZO  ['Clothing, Shoes & Jewelry', 'Women', 'Shoes'...
# 999999  B00HGABX0I  ['Clothing, Shoes & Jewelry', 'Women', 'Shoes'...
#
#                                             product_title subcategory gender
# 0       Birki's Super Pu, Black, 44 M EU (13 Women /11...       Shoes    fem
# 1       Birki's Super Pu, Black, 44 M EU (13 Women /11...       Shoes    fem
# 2       Birki's Super Pu, Black, 44 M EU (13 Women /11...       Shoes    fem
# 3       Birki's Super Pu, Black, 44 M EU (13 Women /11...       Shoes    fem
# 4       Birki's Super Pu, Black, 44 M EU (13 Women /11...       Shoes    fem
# ...                                                   ...         ...    ...
# 999995                     KEEN Women's Koven Hiking Shoe       Shoes    fem
# 999996     KEEN Women's Durand Low Waterproof Hiking Shoe       Shoes    fem
# 999997     KEEN Women's Durand Low Waterproof Hiking Shoe       Shoes    fem
# 999998     KEEN Women's Durand Low Waterproof Hiking Shoe       Shoes    fem
# 999999                     KEEN Women's Koven Hiking Shoe       Shoes    fem
#
# [1000000 rows x 7 columns]

# %% [markdown]
# Давайте обучим на данных w2v и посмотрим, что похоже на слово shoes

# %%
import gensim
from string import punctuation
from collections import Counter

# %%
def process(x):
    x = x.lower().strip()
    for char in punctuation:
        x = x.replace(char, ' ')
    return x.split()

# %%
sent_corp = [process(i) for i in df_fem[:500000].review_text.tolist()]

# %%
model = gensim.models.Word2Vec(sent_corp, window=3, sg=0)

# %%
model.wv.most_similar('shoes', topn=15)
# Out:
# [('sneakers', 0.857509970664978),
#  ('sandals', 0.8315462470054626),
#  ('boots', 0.7668453454971313),
#  ('slippers', 0.7075112462043762),
#  ('flats', 0.7033877968788147),
#  ('clogs', 0.7003418803215027),
#  ('sandles', 0.6955327391624451),
#  ('pumps', 0.6485317945480347),
#  ('crocs', 0.6422736644744873),
#  ('thongs', 0.6319131851196289),
#  ('rainboots', 0.6299407482147217),
#  ('nikes', 0.6109881401062012),
#  ('flipflops', 0.5970699787139893),
#  ('mules', 0.5959691405296326),
#  ('loafers', 0.5838873386383057)]

# %%
bow = []
for i in sent_corp:
    bow += i
word_counts = Counter(bow)

# %%
print('shoes', word_counts['shoes'])
for i in model.wv.most_similar('shoes', topn=15):
    print(i[0], word_counts[i[0]])
# Out:
# shoes 198417
# sneakers 8405
# sandals 33914
# boots 59079
# slippers 17173
# flats 4280
# clogs 3715
# sandles 869
# pumps 1109
# crocs 9501
# thongs 649
# rainboots 164
# nikes 391
# flipflops 479
# mules 370
# loafers 606

# %%
print('shoe', word_counts['shoe'])
for i in model.wv.most_similar('shoe', topn=15):
    print(i[0], word_counts[i[0]])
# Out:
# shoe 112744
# sandal 13395
# boot 23273
# sneaker 3575
# slipper 5285
# clog 1783
# sandle 377
# pump 800
# product 12256
# loafer 534
# item 2863
# model 2386
# shoes 198417
# style 25888
# mule 245
# design 5633

# %% [markdown]
# Запомним самые частотные. Так как в дальнейшем нас просят проанализировать названия по 5 продуктам, выберем 5 помимо shoes: shoes, boots, slippers, sandals, crocs, sneakers

# %%
SHOE_NAMES = ['shoe', 'boot', 'slipper', 'sandal', 'crocs', 'sneaker']

# %%
vecs = [model.wv['shoes']]
words = ['shoes']
for i in model.wv.most_similar('shoes', topn=15):
    vecs.append(model.wv[i[0]])
    words.append(i[0])

# %%
from sklearn.manifold import TSNE
from matplotlib import pyplot as plt

# %%
tsne = TSNE(n_components=2, init='pca', random_state=42, verbose=2)
reduced = tsne.fit_transform(vecs)
# Out:
# [t-SNE] Computing 15 nearest neighbors...
# [t-SNE] Indexed 16 samples in 0.000s...
# [t-SNE] Computed neighbors for 16 samples in 0.003s...
# [t-SNE] Computed conditional probabilities for sample 16 / 16
# [t-SNE] Mean sigma: 1125899906842624.000000
# [t-SNE] Computed conditional probabilities in 0.004s
# [t-SNE] Iteration 50: error = 86.5245514, gradient norm = 0.3819191 (50 iterations in 0.010s)
# [t-SNE] Iteration 100: error = 43.8006210, gradient norm = 0.0259324 (50 iterations in 0.009s)
# [t-SNE] Iteration 150: error = 43.7193222, gradient norm = 0.0185806 (50 iterations in 0.009s)
# [t-SNE] Iteration 200: error = 53.7985420, gradient norm = 0.0146592 (50 iterations in 0.008s)
# [t-SNE] Iteration 250: error = 72.9067841, gradient norm = 0.0420057 (50 iterations in 0.008s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 72.906784
# [t-SNE] Iteration 300: error = 0.8698807, gradient norm = 0.0009660 (50 iterations in 0.009s)
# [t-SNE] Iteration 350: error = 0.6600602, gradient norm = 0.0003700 (50 iterations in 0.008s)
# [t-SNE] Iteration 400: error = 0.5742779, gradient norm = 0.0002275 (50 iterations in 0.009s)
# [t-SNE] Iteration 450: error = 0.5122011, gradient norm = 0.0001891 (50 iterations in 0.008s)
# [t-SNE] Iteration 500: error = 0.4446166, gradient norm = 0.0001735 (50 iterations in 0.008s)
# [t-SNE] Iteration 550: error = 0.3868147, gradient norm = 0.0001098 (50 iterations in 0.008s)
# [t-SNE] Iteration 600: error = 0.3703064, gradient norm = 0.0000545 (50 iterations in 0.008s)
# [t-SNE] Iteration 650: error = 0.3662120, gradient norm = 0.0000376 (50 iterations in 0.007s)
# [t-SNE] Iteration 700: error = 0.3657004, gradient norm = 0.0000295 (50 iterations in 0.007s)
# [t-SNE] Iteration 750: error = 0.3639027, gradient norm = 0.0000239 (50 iterations in 0.007s)
# [t-SNE] Iteration 800: error = 0.3603956, gradient norm = 0.0000203 (50 iterations in 0.007s)
# [t-SNE] Iteration 850: error = 0.3594914, gradient norm = 0.0000156 (50 iterations in 0.007s)
# [t-SNE] Iteration 900: error = 0.3588110, gradient norm = 0.0000139 (50 iterations in 0.007s)
# [t-SNE] Iteration 950: error = 0.3594457, gradient norm = 0.0000165 (50 iterations in 0.007s)
# [t-SNE] Iteration 1000: error = 0.3569648, gradient norm = 0.0000156 (50 iterations in 0.007s)
# [t-SNE] KL divergence after 1000 iterations: 0.356965

# %%
inds = range(16)
x_coords = [coords[0] for coords in reduced[inds]]
y_coords = [coords[1] for coords in reduced[inds]]

# %% [markdown]
# Я думала, что можно будет как-то красиво объеднить слова в группы, например, сказать что flats и slippers скорее одно и то же, но не получлось

# %%
for (x, y, word) in zip(x_coords, y_coords, words):
    plt.scatter(x, y, marker='.', color='blue')
    plt.text(x+0.01, y+0.01, word, fontsize=9)
plt.show()

# %% [markdown]
# Посмотрим, называют ли обувь словами из заголовка продукта

# %%
intersections = []
for title, text in zip(df_fem.product_title.tolist()[:500000], sent_corp):
    title_set = set(process(str(title)))
    text_set = set(text)
    inter = text_set.intersection(title_set)
    if inter:
        intersections.append(' '.join(list(inter)))

# %%
count_inters = Counter(intersections)
count_inters.most_common(100)
# Out:
# [('s', 17079),
#  ('boot', 5728),
#  ('flip', 4795),
#  ('shoe', 4260),
#  ('converse', 4159),
#  ('toms', 4052),
#  ('shoes', 3762),
#  ('on', 3744),
#  ('crocs', 3394),
#  ('sandal', 3308),
#  ('and', 2396),
#  ('keds', 2283),
#  ('teva', 2179),
#  ('all', 1924),
#  ('flop flip', 1454),
#  ('boots', 1441),
#  ('skechers', 1286),
#  ('vans', 1281),
#  ('birkenstock', 1211),
#  ('slipper', 1175),
#  ('flip flops', 1092),
#  ('boot s', 1089),
#  ('sandals', 1082),
#  ('keen', 1080),
#  ('women s', 898),
#  ('for', 880),
#  ('on toms', 865),
#  ('converse all', 809),
#  ('clarks', 792),
#  ('slippers', 747),
#  ('teva s', 729),
#  ('ugg', 726),
#  ('on slip', 716),
#  ('minnetonka', 710),
#  ('hiking', 708),
#  ('flip teva', 667),
#  ('the', 660),
#  ('chuck', 658),
#  ('on s', 643),
#  ('sneaker', 611),
#  ('walking', 599),
#  ('shoes toms', 588),
#  ('spirit easy', 587),
#  ('leather', 580),
#  ('jambu', 579),
#  ('frye', 578),
#  ('flat', 566),
#  ('shoe s', 556),
#  ('women', 511),
#  ('rain', 498),
#  ('running', 485),
#  ('bass', 484),
#  ('water', 484),
#  ('reef', 476),
#  ('sandal s', 461),
#  ('flip flops for', 461),
#  ('aerosoles', 457),
#  ('propet', 456),
#  ('shoes s', 437),
#  ('easy', 434),
#  ('new balance', 433),
#  ('up', 424),
#  ('ecco', 414),
#  ('saucony', 413),
#  ('shoes on', 408),
#  ('nine west', 399),
#  ('dansko', 394),
#  ('merrell', 377),
#  ('alegria', 356),
#  ('nike', 355),
#  ('flip s', 347),
#  ('clog', 333),
#  ('frye boot', 328),
#  ('green daniel', 318),
#  ('with', 316),
#  ('toms s', 315),
#  ('shoe running', 309),
#  ('shoe walking', 305),
#  ('ballet', 298),
#  ('bearpaw', 296),
#  ('work', 292),
#  ('isotoner', 288),
#  ('keen s', 277),
#  ('in', 273),
#  ('chuck taylor', 267),
#  ('foam memory', 261),
#  ('i', 258),
#  ('naturalizer', 251),
#  ('crocs and', 251),
#  ('pump', 249),
#  ('dr martens', 243),
#  ('m', 242),
#  ('slip', 242),
#  ('fitflop', 237),
#  ('ariat', 233),
#  ('crocs s', 224),
#  ('reef flops flip', 223),
#  ('shoes on toms', 222),
#  ('keds s', 221),
#  ('sanuk', 213)]

# %% [markdown]
# Что мы отсюда видим? Что в ботинках могут появляться:
#
# 1. Бренды
# 2. Размеры
# 3. Цель (running, walking, hiking)
#
# Давайте сразу выберем бренды

# %%
brands = [i[0] for i in count_inters.most_common(100) if len(i[0]) > 3]

# %%
def process_upper(x):
    x = x.strip()
    for char in punctuation:
        x = x.replace(char, ' ')
    return x.split()

# %%
up_corp = [process_upper(i) for i in df_fem[:500000].review_text.tolist()]

# %%
intersections_up = []
for title, text in zip(df_fem.product_title.tolist()[:500000], up_corp):
    title_set = set(process_upper(str(title)))
    text_set = set(text)
    inter = text_set.intersection(title_set)
    if inter:
        intersections_up.append(' '.join(list(inter)))

# %%
count_inters_up = Counter(intersections_up)
count_inters_up.most_common(100)
# Out:
# [('s', 28029),
#  ('and', 3962),
#  ('Teva', 2836),
#  ('Converse', 2255),
#  ('for', 2247),
#  ('Keds', 2213),
#  ('Crocs', 2089),
#  ('Birkenstock', 1471),
#  ('on', 1442),
#  ('TOMS', 1295),
#  ('Skechers', 1270),
#  ('Teva s', 964),
#  ('Minnetonka', 849),
#  ('Reef', 805),
#  ('Vans', 735),
#  ('New Balance', 726),
#  ('Propet', 601),
#  ('Jambu', 592),
#  ('Chuck', 581),
#  ('Bass', 572),
#  ('Easy Spirit', 568),
#  ('Saucony', 567),
#  ('Merrell', 553),
#  ('Clarks', 492),
#  ('Dansko', 452),
#  ('Aerosoles', 444),
#  ('UGG', 398),
#  ('on s', 381),
#  ('Daniel Green', 379),
#  ('Nine West', 376),
#  ('Alegria', 361),
#  ('and s', 359),
#  ('I', 328),
#  ('8', 316),
#  ('Reef for', 305),
#  ('Sanuk', 298),
#  ('Dr Martens', 287),
#  ('with and', 283),
#  ('Taylor Chuck', 280),
#  ('All', 270),
#  ('Keds s', 265),
#  ('Naturalizer', 263),
#  ('Ariat', 253),
#  ('Crocs and', 253),
#  ('Minnetonka s', 244),
#  ('in', 225),
#  ('with', 221),
#  ('Merrell s', 220),
#  ('Crocs s', 218),
#  ('The', 217),
#  ('Sperry', 215),
#  ('Capezio', 212),
#  ('for and', 212),
#  ('Trotters', 201),
#  ('ECCO', 195),
#  ('up', 191),
#  ('Timberland', 186),
#  ('TOMS s', 183),
#  ('Easy', 177),
#  ('Saucony s', 173),
#  ('Franco Sarto', 170),
#  ('Jambu s', 170),
#  ('Pleaser', 169),
#  ('Sorel', 167),
#  ('Dansko s', 167),
#  ('Women s', 166),
#  ('TOMS on', 162),
#  ('Boot', 161),
#  ('Bearpaw', 159),
#  ('Birkenstock s', 157),
#  ('Flip', 155),
#  ('Scholl Dr s', 151),
#  ('Walking Cradles', 149),
#  ('Teva Olowahu', 146),
#  ('FitFlop', 146),
#  ('Dr', 145),
#  ('Skechers s', 145),
#  ('New Balance s', 145),
#  ('Propet s', 144),
#  ('Shoe', 143),
#  ('Shoes', 143),
#  ('Sanuk s', 143),
#  ('Puppies Hush', 137),
#  ('UGG s', 135),
#  ('Ryka', 135),
#  ('Converse s', 130),
#  ('Nike', 128),
#  ('Havaianas', 126),
#  ('2', 123),
#  ('Martens', 123),
#  ('Brooks', 123),
#  ('Converse Taylor Chuck', 120),
#  ('Chaco', 120),
#  ('MBT', 119),
#  ('Olowahu', 115),
#  ('Yellow Box', 114),
#  ('of', 113),
#  ('Grasshoppers', 110),
#  ('Sperry s', 109),
#  ('Yucatan', 109)]

# %% [markdown]
# Можно выбрать бренды из списка выше, а можно, например, сделать фильтр по частотности через список, который мы считали для текста в нижнем регистре

# %%
brands_up = [i[0].lower() for i in count_inters_up.most_common(100) if len(i[0]) > 3]

# %%
brands_final = list(set(brands).intersection(set(brands_up)))
brands_final
# Out:
# ['ecco',
#  'teva s',
#  'easy',
#  'crocs s',
#  'birkenstock',
#  'nine west',
#  'dr martens',
#  'nike',
#  'clarks',
#  'keds s',
#  'reef',
#  'new balance',
#  'ariat',
#  'chuck',
#  'sanuk',
#  'crocs and',
#  'propet',
#  'merrell',
#  'alegria',
#  'with',
#  'teva',
#  'flip',
#  'converse',
#  'boot',
#  'toms',
#  'on s',
#  'bass',
#  'aerosoles',
#  'jambu',
#  'dansko',
#  'keds',
#  'fitflop',
#  'skechers',
#  'women s',
#  'shoe',
#  'vans',
#  'crocs',
#  'shoes',
#  'saucony',
#  'naturalizer',
#  'bearpaw',
#  'minnetonka',
#  'toms s']

# %% [markdown]
# Тут меньше брендов и больше мусора, зато мы понимаем, что тут бренды самые значимые

# %% [markdown]
# # Соберем n-граммы

# %%
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.util import ngrams
from nltk.collocations import *
import tqdm
tqdm.notebook.tqdm().pandas()


lemmatizer = WordNetLemmatizer()
# Out:
# 0it [00:00, ?it/s]

# %%
df_fem = df_fem[:500000]

# %%
def full_process(x):

    x = x.lower().strip()
    tokens = word_tokenize(x)
    clean_text = ''
    for i in tokens:
        if i.isalpha():
            clean_text = clean_text + ' ' + lemmatizer.lemmatize(i)
    return clean_text

# %%
df_fem['clean_review'] = df_fem['review_text'].progress_apply(lambda x: full_process(x))
# Out:
#   0%|          | 0/500000 [00:00<?, ?it/s]

# %%
df_fem.to_csv('fem_shoes.csv')

# %%
SHOE_NAMES
# Out:
# ['shoe', 'boot', 'slipper', 'sandal', 'crocs', 'sneaker']

# %% [markdown]
# ### Биграммы

# %%
n = 2
bigrams = ngrams(' '.join(df_fem['clean_review']).split(), n)

# %%
bi = Counter(bigrams)

# %%
shoe_bigrams = {shoe : [] for shoe in SHOE_NAMES}
for bigram in bi.most_common():
    for shoe in shoe_bigrams.keys():
        if shoe in bigram[0]:
            shoe_bigrams[shoe].append(bigram)

# %%
df_bigrams = pd.DataFrame({i : [' '.join(j[0]) for j in shoe_bigrams[i][:150]] for i in SHOE_NAMES})

# %%
df_bigrams
# Out:
#                shoe            boot          slipper          sandal  \
# 0        these shoe      these boot    these slipper    these sandal
# 1          the shoe        the boot        slipper i        sandal i
# 2            shoe i          boot i      the slipper      the sandal
# 3          shoe are        boot are      slipper are      sandal are
# 4         this shoe        boot and        a slipper      sandal and
# ..              ...             ...              ...             ...
# 145      style shoe       boot well     have slipper   pretty sandal
# 146       flat shoe         boot no      slipper did    water sandal
# 147      shoe super      boot there  awesome slipper    right sandal
# 148  wonderful shoe  wonderful boot     slipper seem  stylish sandal
# 149    balance shoe       boot come   bootie slipper     shoe sandal
#
#            crocs         sneaker
# 0       of crocs   these sneaker
# 1        crocs i       sneaker i
# 2    these crocs     sneaker and
# 3      crocs are     the sneaker
# 4      the crocs     sneaker are
# ..           ...             ...
# 145   hope crocs   sneaker style
# 146  tried crocs   sneaker comfy
# 147  crocs after      up sneaker
# 148    any crocs      sneaker ha
# 149   them crocs  propet sneaker
#
# [150 rows x 6 columns]

# %% [markdown]
# ### Триграммы

# %%
n = 3
trigrams = ngrams(' '.join(df_fem['clean_review']).split(), n)
tri = Counter(trigrams)

# %%
shoe_trigrams = {shoe : [] for shoe in SHOE_NAMES}
for trigram in tri.most_common():
    for shoe in shoe_trigrams.keys():
        if shoe in trigram[0]:
            shoe_trigrams[shoe].append(trigram)

# %%
df_trigrams = pd.DataFrame({i : [' '.join(j[0]) for j in shoe_trigrams[i][:150]] for i in SHOE_NAMES})

# %%
df_trigrams
# Out:
#                     shoe                boot                slipper  \
# 0        love these shoe     love these boot     love these slipper
# 1         these shoe are      these boot are      these slipper are
# 2            of the shoe         of the boot       slipper they are
# 3           these shoe i        these boot i         slipper i have
# 4            shoe i have       boot they are        pair of slipper
# ..                   ...                 ...                    ...
# 145     normal shoe size  wearing these boot         the slipper wa
# 146  recommend this shoe         the boot so      slipper i ordered
# 147           shoe fit a         boot were a       these slipper my
# 148       walking shoe i       this boot and        slipper is very
# 149   ordered these shoe        of boot that  ordered these slipper
#
#                    sandal                  crocs              sneaker
# 0       love these sandal          pair of crocs   love these sneaker
# 1        these sandal are           i love crocs      pair of sneaker
# 2           sandal i have           crocs i have    these sneaker are
# 3          these sandal i        these crocs are       sneaker i have
# 4         sandal they are             of crocs i     sneaker they are
# ..                    ...                    ...                  ...
# 145  ordered these sandal  crocs are comfortable      sneaker but the
# 146        sandal so much           crocs do not     with the sneaker
# 147       this sandal and       other crocs that  sneaker are perfect
# 148      sandal they were         that the crocs      sneaker that is
# 149         sandal if you           to the crocs       sneaker with a
#
# [150 rows x 6 columns]

# %% [markdown]
# Давайте теперь посмотрим на лучшие n-граммы по метрикам коллокаций

# %% [markdown]
# ## Ранжирование по коллокационным метрикам

# %% [markdown]
# Я решила использовать PMI, likelihood ratio и jaccard score. Для выделения биграмм я сделала фильтр частотности 10. Еще я сделала отдельный столбец с подсчетом частотности. В итоге я решила, что интереснее не выбирать лучшую метрику, а взять их агрегацию (получить пересечение слов из рейтингов по всем метрикам). Оно в итоге и выводится в final_bigrams и final_trigrams

# %%
bigram_measures = nltk.collocations.BigramAssocMeasures()
finder = BigramCollocationFinder.from_words(' '.join(df_fem['clean_review']).split())
finder.apply_freq_filter(10)

# %%
for shoe in tqdm.tqdm(SHOE_NAMES):
    lem = lemmatizer.lemmatize(shoe)
    rate = [i for i in finder.nbest(bigram_measures.pmi, 100000000000) if lem in i][:150]
    df_bigrams[f'{lem}_pmi'] = [' '.join(i) for i in rate]
# Out:
# 100%|█████████████████████████████████████████████| 6/6 [00:03<00:00,  1.63it/s]

# %%
for shoe in tqdm.tqdm(SHOE_NAMES):
    lem = lemmatizer.lemmatize(shoe)
    rate = [i for i in finder.nbest(bigram_measures.likelihood_ratio, 100000000000) if lem in i][:150]
    df_bigrams[f'{lem}_likelihood'] = [' '.join(i) for i in rate]
# Out:
# 100%|█████████████████████████████████████████████| 6/6 [00:05<00:00,  1.12it/s]

# %%
for shoe in tqdm.tqdm(SHOE_NAMES):
    lem = lemmatizer.lemmatize(shoe)
    rate = [i for i in finder.nbest(bigram_measures.jaccard, 100000000000) if lem in i][:150]
    df_bigrams[f'{lem}_jaccard'] = [' '.join(i) for i in rate]
# Out:
# 100%|█████████████████████████████████████████████| 6/6 [00:03<00:00,  1.71it/s]

# %%
final_bigrams = {}
columns = ['{}', '{}_jaccard', '{}_pmi', '{}_likelihood']
for shoe in tqdm.tqdm(SHOE_NAMES):
    lem = lemmatizer.lemmatize(shoe)
    bigram_set = set(df_bigrams[columns[0].format(lem)].tolist())
    for col in columns[1:]:
        bigram_set = set(df_bigrams[col.format(lem)].tolist()).intersection(bigram_set)
    final_bigrams[lem] = bigram_set
# Out:
# 100%|███████████████████████████████████████████| 6/6 [00:00<00:00, 2984.92it/s]

# %%
df_bigrams
# Out:
#                shoe            boot          slipper          sandal  \
# 0        these shoe      these boot    these slipper    these sandal
# 1          the shoe        the boot        slipper i        sandal i
# 2            shoe i          boot i      the slipper      the sandal
# 3          shoe are        boot are      slipper are      sandal are
# 4         this shoe        boot and        a slipper      sandal and
# ..              ...             ...              ...             ...
# 145      style shoe       boot well     have slipper   pretty sandal
# 146       flat shoe         boot no      slipper did    water sandal
# 147      shoe super      boot there  awesome slipper    right sandal
# 148  wonderful shoe  wonderful boot     slipper seem  stylish sandal
# 149    balance shoe       boot come   bootie slipper     shoe sandal
#
#            crocs         sneaker        shoe_pmi        boot_pmi  \
# 0       of crocs   these sneaker       shoe horn     cowboy boot
# 1        crocs i       sneaker i     tennis shoe   tactical boot
# 2    these crocs     sneaker and  atheletic shoe     combat boot
# 3      crocs are     the sneaker      thise shoe      lexis boot
# 4      the crocs     sneaker are  shoe stretcher    paddock boot
# ..           ...             ...             ...             ...
# 145   hope crocs   sneaker style    leisure shoe    boot arrived
# 146  tried crocs   sneaker comfy    grandma shoe        boot are
# 147  crocs after      up sneaker       avia shoe  fantastic boot
# 148    any crocs      sneaker ha      witch shoe       best boot
# 149   them crocs  propet sneaker          j shoe    similar boot
#
#           slipper_pmi      sandal_pmi  ...   slipper_likelihood  \
# 0          dg slipper   lucena sandal  ...        these slipper
# 1     bedroom slipper    ibiza sandal  ...        house slipper
# 2      greene slipper   sharon sandal  ...          slipper are
# 3    dearfoam slipper  sunbeat sandal  ...      bedroom slipper
# 4      howser slipper  yucatan sandal  ...        green slipper
# ..                ...             ...  ...                  ...
# 145    slipper person     same sandal  ...     slipper although
# 146      slipper stay     sandal that  ...          slipper too
# 147      slipper over   sturdy sandal  ...           no slipper
# 148      most slipper     nice sandal  ...         soft slipper
# 149        slipper or     sandal meet  ...  inexpensive slipper
#
#      sandal_likelihood crocs_likelihood sneaker_likelihood shoe_jaccard  \
# 0         these sandal         of crocs      these sneaker   these shoe
# 1          teva sandal      these crocs          sneaker i     the shoe
# 2          this sandal      other crocs      dance sneaker    this shoe
# 3             sandal i        crocs are    fashion sneaker     shoe are
# 4           sandal are       love crocs        sneaker but       shoe i
# ..                 ...              ...                ...          ...
# 145  particular sandal       size crocs    sneaker ordered  shoe bought
# 146         sandal get        out crocs       sneaker when    shoe lace
# 147      athens sandal    thought crocs      sneaker these   style shoe
# 148        sandal more         crocs at        fun sneaker   shoe there
# 149    okabashi sandal        try crocs  excellent sneaker  buying shoe
#
#      boot_jaccard  slipper_jaccard   sandal_jaccard      crocs_jaccard  \
# 0      these boot    house slipper     these sandal        other crocs
# 1        boot are    these slipper      teva sandal     original crocs
# 2       this boot    green slipper      this sandal      regular crocs
# 3        the boot  bedroom slipper      keen sandal  traditional crocs
# 4       rain boot   ballet slipper  favorite sandal       bistro crocs
# ..            ...              ...              ...                ...
# 145  stylish boot    slipper super   sandal without         crocs keep
# 146     boot good     slipper soft   sandal arrived        crocs these
# 147  western boot      slipper now      mush sandal           if crocs
# 148    boot super      slipper not        sandal my        crocs never
# 149      boot out     slipper than      sandal came          crocs did
#
#       sneaker_jaccard
# 0       dance sneaker
# 1     fashion sneaker
# 2    converse sneaker
# 3        keds sneaker
# 4     classic sneaker
# ..                ...
# 145   stylish sneaker
# 146     sneaker until
# 147       sneaker yet
# 148   sneaker arrived
# 149    school sneaker
#
# [150 rows x 24 columns]

# %%
final_bigrams
# Out:
# {'shoe': {'athletic shoe',
#   'clark shoe',
#   'dance shoe',
#   'favorite shoe',
#   'finding shoe',
#   'left shoe',
#   'running shoe',
#   'shoe itself',
#   'street shoe',
#   'tennis shoe',
#   'these shoe'},
#  'boot': {'ariat boot',
#   'awesome boot',
#   'bearpaw boot',
#   'beautiful boot',
#   'best boot',
#   'boot are',
#   'boot arrived',
#   'boot cut',
#   'boot itself',
#   'boot shaft',
#   'combat boot',
#   'cowboy boot',
#   'emu boot',
#   'favorite boot',
#   'frye boot',
#   'gorgeous boot',
#   'hiking boot',
#   'left boot',
#   'muck boot',
#   'rain boot',
#   'riding boot',
#   'rubber boot',
#   'snow boot',
#   'tall boot',
#   'these boot',
#   'this boot',
#   'timberland boot',
#   'ugg boot',
#   'waterproof boot',
#   'winter boot'},
#  'slipper': {'acorn slipper',
#   'awesome slipper',
#   'ballerina slipper',
#   'ballet slipper',
#   'beautiful slipper',
#   'bedroom slipper',
#   'best slipper',
#   'bootie slipper',
#   'comfortable slipper',
#   'comfy slipper',
#   'cozy slipper',
#   'dormie slipper',
#   'favorite slipper',
#   'friend slipper',
#   'great slipper',
#   'green slipper',
#   'haflinger slipper',
#   'house slipper',
#   'indoor slipper',
#   'isotoner slipper',
#   'left slipper',
#   'like slipper',
#   'new slipper',
#   'nice slipper',
#   'of slipper',
#   'old slipper',
#   'only slipper',
#   'other slipper',
#   'quality slipper',
#   'regular slipper',
#   'same slipper',
#   'shearling slipper',
#   'sheepskin slipper',
#   'slipper are',
#   'slipper around',
#   'slipper arrived',
#   'slipper because',
#   'slipper before',
#   'slipper but',
#   'slipper ever',
#   'slipper for',
#   'slipper from',
#   'slipper he',
#   'slipper however',
#   'slipper i',
#   'slipper or',
#   'slipper run',
#   'slipper she',
#   'slipper since',
#   'slipper that',
#   'slipper they',
#   'slipper were',
#   'slipper when',
#   'slipper which',
#   'soft slipper',
#   'summer slipper',
#   'the slipper',
#   'their slipper',
#   'these slipper',
#   'this slipper',
#   'ugg slipper',
#   'warm slipper',
#   'wearing slipper',
#   'winter slipper',
#   'wonderful slipper',
#   'wool slipper'},
#  'sandal': {'attractive sandal',
#   'bass sandal',
#   'beautiful sandal',
#   'best sandal',
#   'birkenstock sandal',
#   'casual sandal',
#   'clark sandal',
#   'comfortable sandal',
#   'croc sandal',
#   'ecco sandal',
#   'everyday sandal',
#   'favorite sandal',
#   'finding sandal',
#   'fitflop sandal',
#   'hiking sandal',
#   'keen sandal',
#   'minnetonka sandal',
#   'newport sandal',
#   'nice sandal',
#   'olowahu sandal',
#   'other sandal',
#   'rainbow sandal',
#   'reef sandal',
#   'same sandal',
#   'sandal are',
#   'sandal before',
#   'sandal ever',
#   'sandal that',
#   'sharon sandal',
#   'sport sandal',
#   'summer sandal',
#   'supportive sandal',
#   'teva sandal',
#   'their sandal',
#   'these sandal',
#   'this sandal',
#   'thong sandal',
#   'type sandal',
#   'wedge sandal',
#   'whisper sandal',
#   'white sandal',
#   'wonderful sandal',
#   'yucatan sandal'},
#  'crocs': {'about crocs',
#   'all crocs',
#   'best crocs',
#   'bistro crocs',
#   'black crocs',
#   'buy crocs',
#   'buying crocs',
#   'by crocs',
#   'classic crocs',
#   'clog crocs',
#   'crocs and',
#   'crocs are',
#   'crocs arrived',
#   'crocs at',
#   'crocs athens',
#   'crocs because',
#   'crocs before',
#   'crocs brand',
#   'crocs but',
#   'crocs came',
#   'crocs clog',
#   'crocs comfort',
#   'crocs do',
#   'crocs fan',
#   'crocs flat',
#   'crocs flip',
#   'crocs for',
#   'crocs ha',
#   'crocs he',
#   'crocs however',
#   'crocs i',
#   'crocs in',
#   'crocs made',
#   'crocs make',
#   'crocs product',
#   'crocs run',
#   'crocs sandal',
#   'crocs since',
#   'crocs so',
#   'crocs specialist',
#   'crocs store',
#   'crocs that',
#   'crocs they',
#   'crocs unisex',
#   'crocs website',
#   'crocs were',
#   'crocs when',
#   'crocs which',
#   'crocs woman',
#   'favorite crocs',
#   'from crocs',
#   'his crocs',
#   'hope crocs',
#   'know crocs',
#   'like crocs',
#   'love crocs',
#   'loved crocs',
#   'many crocs',
#   'most crocs',
#   'my crocs',
#   'new crocs',
#   'normal crocs',
#   'of crocs',
#   'old crocs',
#   'original crocs',
#   'other crocs',
#   'owned crocs',
#   'particular crocs',
#   'previous crocs',
#   'regular crocs',
#   'some crocs',
#   'specialist crocs',
#   'standard crocs',
#   'style crocs',
#   'than crocs',
#   'that crocs',
#   'the crocs',
#   'these crocs',
#   'traditional crocs',
#   'tried crocs',
#   'typical crocs',
#   'usual crocs',
#   'wear crocs',
#   'wearing crocs',
#   'wish crocs',
#   'with crocs',
#   'worn crocs'},
#  'sneaker': {'any sneaker',
#   'athletic sneaker',
#   'average sneaker',
#   'awesome sneaker',
#   'balance sneaker',
#   'best sneaker',
#   'black sneaker',
#   'canvas sneaker',
#   'casual sneaker',
#   'champion sneaker',
#   'classic sneaker',
#   'comfortable sneaker',
#   'comfy sneaker',
#   'converse sneaker',
#   'cute sneaker',
#   'dance sneaker',
#   'everyday sneaker',
#   'fashion sneaker',
#   'favorite sneaker',
#   'great sneaker',
#   'in sneaker',
#   'keds sneaker',
#   'leather sneaker',
#   'lightweight sneaker',
#   'like sneaker',
#   'looking sneaker',
#   'many sneaker',
#   'men sneaker',
#   'most sneaker',
#   'new sneaker',
#   'nice sneaker',
#   'nike sneaker',
#   'normal sneaker',
#   'of sneaker',
#   'old sneaker',
#   'only sneaker',
#   'other sneaker',
#   'propet sneaker',
#   'regular sneaker',
#   'running sneaker',
#   'saucony sneaker',
#   'skechers sneaker',
#   'sketcher sneaker',
#   'sneaker and',
#   'sneaker are',
#   'sneaker because',
#   'sneaker but',
#   'sneaker ever',
#   'sneaker fit',
#   'sneaker for',
#   'sneaker however',
#   'sneaker i',
#   'sneaker is',
#   'sneaker look',
#   'sneaker or',
#   'sneaker run',
#   'sneaker since',
#   'sneaker so',
#   'sneaker that',
#   'sneaker they',
#   'sneaker type',
#   'sneaker we',
#   'sneaker were',
#   'sneaker which',
#   'sneaker without',
#   'spirit sneaker',
#   'summer sneaker',
#   'than sneaker',
#   'their sneaker',
#   'these sneaker',
#   'this sneaker',
#   'typical sneaker',
#   'velcro sneaker',
#   'walking sneaker',
#   'wear sneaker',
#   'wearing sneaker',
#   'white sneaker',
#   'woman sneaker'}}

# %% [markdown]
# Вообще, если просмотреть бираммы, то видно, что самые осмысленные NE имеют формат X shoe_name. Давайте такие и выведем как финальный результат

# %%
for shoe in final_bigrams.keys():
    print('Для продукта', shoe + ':')
    for i in final_bigrams[shoe]:
        if i.split()[1] == shoe and len(i.split()[0]) >3:
            print(i)
    print()
# Out:
# Для продукта shoe:
# finding shoe
# tennis shoe
# running shoe
# these shoe
# athletic shoe
# left shoe
# street shoe
# clark shoe
# dance shoe
# favorite shoe
#
# Для продукта boot:
# muck boot
# beautiful boot
# rain boot
# awesome boot
# combat boot
# frye boot
# gorgeous boot
# this boot
# ariat boot
# left boot
# winter boot
# hiking boot
# snow boot
# tall boot
# timberland boot
# riding boot
# rubber boot
# best boot
# favorite boot
# these boot
# bearpaw boot
# waterproof boot
# cowboy boot
#
# Для продукта slipper:
# great slipper
# quality slipper
# acorn slipper
# house slipper
# beautiful slipper
# sheepskin slipper
# ballet slipper
# shearling slipper
# awesome slipper
# isotoner slipper
# soft slipper
# cozy slipper
# only slipper
# friend slipper
# favorite slipper
# same slipper
# comfortable slipper
# comfy slipper
# wool slipper
# these slipper
# regular slipper
# summer slipper
# green slipper
# other slipper
# like slipper
# bootie slipper
# their slipper
# bedroom slipper
# left slipper
# wonderful slipper
# indoor slipper
# warm slipper
# ballerina slipper
# nice slipper
# wearing slipper
# haflinger slipper
# dormie slipper
# winter slipper
# this slipper
# best slipper
#
# Для продукта sandal:
# birkenstock sandal
# hiking sandal
# whisper sandal
# beautiful sandal
# rainbow sandal
# casual sandal
# type sandal
# other sandal
# wedge sandal
# minnetonka sandal
# clark sandal
# teva sandal
# summer sandal
# thong sandal
# this sandal
# olowahu sandal
# sport sandal
# best sandal
# nice sandal
# same sandal
# attractive sandal
# white sandal
# sharon sandal
# keen sandal
# their sandal
# everyday sandal
# ecco sandal
# yucatan sandal
# supportive sandal
# croc sandal
# comfortable sandal
# wonderful sandal
# favorite sandal
# newport sandal
# these sandal
# reef sandal
# finding sandal
# fitflop sandal
# bass sandal
#
# Для продукта crocs:
# tried crocs
# regular crocs
# particular crocs
# clog crocs
# typical crocs
# wear crocs
# owned crocs
# buying crocs
# love crocs
# style crocs
# many crocs
# specialist crocs
# from crocs
# worn crocs
# best crocs
# wish crocs
# like crocs
# hope crocs
# that crocs
# favorite crocs
# loved crocs
# previous crocs
# most crocs
# know crocs
# with crocs
# other crocs
# classic crocs
# traditional crocs
# these crocs
# some crocs
# original crocs
# wearing crocs
# bistro crocs
# black crocs
# about crocs
# normal crocs
# standard crocs
# than crocs
# usual crocs
#
# Для продукта sneaker:
# skechers sneaker
# like sneaker
# most sneaker
# sketcher sneaker
# other sneaker
# white sneaker
# best sneaker
# woman sneaker
# regular sneaker
# dance sneaker
# normal sneaker
# looking sneaker
# black sneaker
# awesome sneaker
# cute sneaker
# these sneaker
# classic sneaker
# nice sneaker
# than sneaker
# fashion sneaker
# comfortable sneaker
# champion sneaker
# everyday sneaker
# wear sneaker
# casual sneaker
# average sneaker
# keds sneaker
# saucony sneaker
# comfy sneaker
# propet sneaker
# canvas sneaker
# many sneaker
# velcro sneaker
# only sneaker
# summer sneaker
# wearing sneaker
# favorite sneaker
# walking sneaker
# their sneaker
# nike sneaker
# typical sneaker
# lightweight sneaker
# this sneaker
# great sneaker
# leather sneaker
# converse sneaker
# athletic sneaker
# running sneaker
# balance sneaker
# spirit sneaker

# %% [markdown]
# # Лучшие триграммы

# %%
trigram_measures = nltk.collocations.TrigramAssocMeasures()
finder = TrigramCollocationFinder.from_words(' '.join(df_fem['clean_review']).split())
finder.apply_freq_filter(10)

# %%
for shoe in tqdm.tqdm(SHOE_NAMES):
    lem = lemmatizer.lemmatize(shoe)
    rate = [i for i in finder.nbest(trigram_measures.pmi, 100000000000) if lem in i][:150]
    df_trigrams[f'{lem}_pmi'] = [' '.join(i) for i in rate]
# Out:
# 100%|█████████████████████████████████████████████| 6/6 [00:11<00:00,  1.88s/it]

# %%
for shoe in tqdm.tqdm(SHOE_NAMES):
    lem = lemmatizer.lemmatize(shoe)
    rate = [i for i in finder.nbest(trigram_measures.likelihood_ratio, 100000000000) if lem in i][:150]
    df_trigrams[f'{lem}_likelihood'] = [' '.join(i) for i in rate]
# Out:
# 100%|█████████████████████████████████████████████| 6/6 [01:28<00:00, 14.73s/it]

# %%
for shoe in tqdm.tqdm(SHOE_NAMES):
    lem = lemmatizer.lemmatize(shoe)
    rate = [i for i in finder.nbest(trigram_measures.jaccard, 100000000000) if lem in i][:150]
    df_trigrams[f'{lem}_jaccard'] = [' '.join(i) for i in rate]
# Out:
# 100%|█████████████████████████████████████████████| 6/6 [00:10<00:00,  1.70s/it]

# %%
final_trigrams = {}
columns = ['{}_jaccard', '{}_pmi', '{}_likelihood']  # Уберем тут просто частотность, чтобы получить побольше вариантов
for shoe in tqdm.tqdm(SHOE_NAMES):
    lem = lemmatizer.lemmatize(shoe)
    trigram_set = set(df_trigrams[columns[0].format(lem)].tolist())
    for col in columns[1:]:
        trigram_set = set(df_trigrams[col.format(lem)].tolist()).intersection(trigram_set)
    final_trigrams[lem] = trigram_set
# Out:
# 100%|███████████████████████████████████████████| 6/6 [00:00<00:00, 7084.97it/s]

# %%
df_trigrams
# Out:
#                     shoe                boot                slipper  \
# 0        love these shoe     love these boot     love these slipper
# 1         these shoe are      these boot are      these slipper are
# 2            of the shoe         of the boot       slipper they are
# 3           these shoe i        these boot i         slipper i have
# 4            shoe i have       boot they are        pair of slipper
# ..                   ...                 ...                    ...
# 145     normal shoe size  wearing these boot         the slipper wa
# 146  recommend this shoe         the boot so      slipper i ordered
# 147           shoe fit a         boot were a       these slipper my
# 148       walking shoe i       this boot and        slipper is very
# 149   ordered these shoe        of boot that  ordered these slipper
#
#                    sandal                  crocs              sneaker  \
# 0       love these sandal          pair of crocs   love these sneaker
# 1        these sandal are           i love crocs      pair of sneaker
# 2           sandal i have           crocs i have    these sneaker are
# 3          these sandal i        these crocs are       sneaker i have
# 4         sandal they are             of crocs i     sneaker they are
# ..                    ...                    ...                  ...
# 145  ordered these sandal  crocs are comfortable      sneaker but the
# 146        sandal so much           crocs do not     with the sneaker
# 147       this sandal and       other crocs that  sneaker are perfect
# 148      sandal they were         that the crocs      sneaker that is
# 149         sandal if you           to the crocs       sneaker with a
#
#                    shoe_pmi               boot_pmi  \
# 0         josef seibel shoe   harley davidson boot
# 1       enzo angiolini shoe          miz mooz boot
# 2         ro hommerson shoe      justin gypsy boot
# 3           bella vita shoe     la canadienne boot
# 4     lindsay phillips shoe  timberland lexis boot
# ..                      ...                    ...
# 145      shoe kept slipping        frye boot which
# 146           non slip shoe        new hiking boot
# 147  shoe arrived yesterday          of sorel boot
# 148      athletic type shoe      love bearpaw boot
# 149   typical converse shoe       harness boot are
#
#                     slipper_pmi               sandal_pmi  ...  \
# 0         daniel greene slipper       jack rogers sandal  ...
# 1    isotoner ballerina slipper       sanuk ibiza sandal  ...
# 2       satin ballerina slipper      pedic walker sandal  ...
# 3          daniel green slipper           dawgs z sandal  ...
# 4              bear paw slipper      ecco yucatan sandal  ...
# ..                          ...                      ...  ...
# 145   comfortable house slipper  love birkenstock sandal  ...
# 146          the slipper itself     sandal that provides  ...
# 147         almost like slipper        sandal all summer  ...
# 148             ugg slipper and  comfortable sandal ever  ...
# 149             left slipper is         love ecco sandal  ...
#
#        slipper_likelihood      sandal_likelihood crocs_likelihood  \
# 0        slipper they are        they are sandal   crocs they are
# 1        they are slipper        sandal they are   they are crocs
# 2         slipper my foot         sandal my foot  crocs flip flop
# 3          slipper i have       flip flop sandal  flip flop crocs
# 4          i have slipper       sandal flip flop     crocs i have
# ..                    ...                    ...              ...
# 145  good quality slipper         to find sandal     i know crocs
# 146  slipper good quality        these sandal is   my other crocs
# 147      these slipper my       these sandal not   style of crocs
# 148     are great slipper        it these sandal     crocs i also
# 149          is a slipper  received these sandal        crocs a i
#
#     sneaker_likelihood           shoe_jaccard         boot_jaccard  \
# 0     they are sneaker        love these shoe      love these boot
# 1     sneaker they are         these shoe are       these boot are
# 2      sneaker my foot            of the shoe         pair of boot
# 3       sneaker i have           pair of shoe          of the boot
# 4      pair of sneaker  most comfortable shoe        boot they are
# ..                 ...                    ...                  ...
# 145     sneaker is not         like this shoe   favorite boot ever
# 146    sneaker since i         these shoe the        into the boot
# 147    all the sneaker        them these shoe  received these boot
# 148    sneaker all the         got these shoe       for these boot
# 149   sneaker from the         buy these shoe         a great boot
#
#           slipper_jaccard           sandal_jaccard          crocs_jaccard  \
# 0    daniel green slipper        love these sandal          pair of crocs
# 1      love these slipper  most comfortable sandal        crocs flip flop
# 2       these slipper are         these sandal are    batali bistro crocs
# 3       best slipper ever           pair of sandal     been wearing crocs
# 4    like wearing slipper         best sandal ever       love these crocs
# ..                    ...                      ...                    ...
# 145     slipper very soft       teva sandal before  crocs are comfortable
# 146     slipper have been          this sandal for         have had crocs
# 147      slipper were too         like this sandal        and these crocs
# 148      the only slipper         open toed sandal            crocs i had
# 149  slipper good quality          love the sandal         in these crocs
#
#               sneaker_jaccard
# 0         new balance sneaker
# 1         easy spirit sneaker
# 2          love these sneaker
# 3             pair of sneaker
# 4    most comfortable sneaker
# ..                        ...
# 145        these sneaker good
# 146   purchased these sneaker
# 147       about these sneaker
# 148          sneaker and they
# 149        sneaker very happy
#
# [150 rows x 24 columns]

# %%
final_trigrams
# Out:
# {'shoe': set(),
#  'boot': set(),
#  'slipper': {'better than slipper',
#   'feel like slipper',
#   'kind of slipper',
#   'love these slipper',
#   'most comfortable slipper',
#   'my favorite slipper',
#   'pair of slipper',
#   'purchased these slipper',
#   'recommend these slipper',
#   'slipper all day',
#   'slipper even though',
#   'slipper fit perfectly',
#   'slipper for year',
#   'slipper highly recommend',
#   'slipper run small',
#   'slipper well made',
#   'slipper year ago',
#   'the best slipper',
#   'these slipper are',
#   'well made slipper'},
#  'sandal': {'flip flop sandal',
#   'most comfortable sandal',
#   'my favorite sandal',
#   'sandal year ago'},
#  'crocs': {'any other crocs',
#   'been wearing crocs',
#   'better than crocs',
#   'bought these crocs',
#   'crocs are great',
#   'crocs are perfect',
#   'crocs at all',
#   'crocs because of',
#   'crocs because they',
#   'crocs can be',
#   'crocs do not',
#   'crocs fit perfectly',
#   'crocs flip flop',
#   'crocs for work',
#   'crocs for year',
#   'crocs have been',
#   'crocs i have',
#   'crocs if you',
#   'crocs my husband',
#   'crocs run large',
#   'crocs these are',
#   'crocs they are',
#   'crocs this is',
#   'crocs very comfortable',
#   'crocs would be',
#   'fan of crocs',
#   'flip flop crocs',
#   'have worn crocs',
#   'i love crocs',
#   'look like crocs',
#   'lot of crocs',
#   'love these crocs',
#   'most comfortable crocs',
#   'my favorite crocs',
#   'my first crocs',
#   'my old crocs',
#   'my other crocs',
#   'never had crocs',
#   'of crocs sandal',
#   'other crocs that',
#   'pair of crocs',
#   'purchased these crocs',
#   'style of crocs',
#   'thank you crocs',
#   'these crocs are',
#   'they are crocs',
#   'type of crocs',
#   'wear crocs all',
#   'wrong with crocs'},
#  'sneaker': {'better than sneaker',
#   'bought these sneaker',
#   'chuck taylor sneaker',
#   'easy spirit sneaker',
#   'feel like sneaker',
#   'instead of sneaker',
#   'look like sneaker',
#   'love these sneaker',
#   'most comfortable sneaker',
#   'my favorite sneaker',
#   'new balance sneaker',
#   'nice looking sneaker',
#   'pair of sneaker',
#   'purchased these sneaker',
#   'recommend these sneaker',
#   'slip on sneaker',
#   'sneaker all day',
#   'sneaker fit perfectly',
#   'sneaker fit well',
#   'sneaker for year',
#   'sneaker if you',
#   'sneaker look great',
#   'sneaker run small',
#   'sneaker so much',
#   'sneaker this is',
#   'sneaker very comfortable',
#   'sneaker very happy',
#   'sneaker would be',
#   'sneaker you can',
#   'the best sneaker',
#   'the only sneaker',
#   'these sneaker are',
#   'too big sneaker',
#   'type of sneaker',
#   'very nice sneaker'}}

# %% [markdown]
# В целом, триграммы вышли не особо осознанными. Полезными могут быть только **flip flop crocs**, **new balance sneaker**, **chuck taylor sneaker** и конструкции **type of X**, **pair of X**

# %% [markdown]
# Вообще я хотела сделать то же самое для мужских ботинок, чтобы сравнить и показать работодателю полную аналитику, но не успела. Будем считать, что мы продаем только женскую обувь
